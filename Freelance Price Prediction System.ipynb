# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# # CRISP-DM :
# ##### I am following CRoss Industry Structured Process for Data Mining is the most popular methodology for data science and advanced analytics projects.
#
# #### It has six steps:
#
# •Business Understanding
#
# •Data Understanding
#
# •Data Preparation
#
# •Modeling
#
# •Validation
#
# •Deployment

# %% [markdown]
# ![download-3.png](attachment:download-3.png)

# %% [markdown]
# # Business Problem Definition :
# ##### " We want to predict the price of freelance employees to offer them the best price for their work by analyzing features present in the dataset."

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# .

# %% [markdown]
# # Data Collection :
#
# #####  " The Data Set is collected from kaggle having records of united state freelancers https://www.kaggle.com/datasets/dataranch/upwork-1 The dataset contain  freelancer records between (2007 and 2021 year) the sample size is about (>5000) records which is used to offer the best price to specific freelancer employee. "
#
# ####  Note : The Data Set Contain about 76 columns I take some important columns for prediction that plays important role for price prediction

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# .

# %% [markdown]
# # Data Understading :
#
# #### Features Definition:
#
# ##### Title : the title of the freelancer what skill he is offering .
#
# ##### Location : Location where the freelancer belongs to .
#
# ##### HourlyRate : Hourly rate what freelancer is offering .
#
# ##### AvgFeedbackScore : Feedback score people give after work is completed .
#
# ##### LastActivity : Last Activity shows when user last login and perform its task .
#
# ##### TotalHoursBilled : What is the total hourly billed charged it is just a total .
#
# ##### TotalFeedbacks : Total Feedbacks given by people .
#
# ##### TotalPortfolioItems : No of Portfolio items shown on the user profile .
#
# ##### Skills : Skill offering by specific user .
#
# ##### RecentAvgFeedbackScore : Recent Average Feeback Score given by people .
#
# ##### RecentTotalFeedbacks : Recent Total No of Feebacks .
#
# ##### RecentHoursBilled : Recent Houly Billed .
#
# ##### TotalHourlyJobs : Totaly Hourly Jobs done by freelancer .
#
# ##### TotalFixedPriceJobs : Total Fixed Price jobs done by freelancer .
#
# ##### CombinedTotalEarnings : Combine Total earning of hourly + Fixed Price Jobs .
#
# ##### CombinedRecentEarnings: Recent Combine Total earning of hourly + Fixed Price Jobs .
#
# ##### MemberSince : When a Person join freelance platform  .

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import sklearn
from scipy.stats import pearsonr
import ast
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Reading Dataset

# %%
Freelance_Data=pd.read_csv('Freelance Price Prediction.csv')

# %% [markdown]
# #### Number of Rows and Columns in the dataset

# %%
print('Total No of Rows are: {} and Total No of Columns are: {}'.format(Freelance_Data.shape[0],Freelance_Data.shape[1]))
# Out:
# Total No of Rows are: 5823 and Total No of Columns are: 17

# %% [markdown]
# #### Printing dataset to check no of columns and rows

# %%
Freelance_Data.head(3)
# Out:
#                         Title  \
# 0  Expert WordPress Developer
# 1        Social Media Manager
# 2          Solution Architect
#
#                                             Location  \
# 0  {'country': 'United States', 'city': 'Chicago'...
# 1  {'country': 'United States', 'city': 'Etna', '...
# 2  {'country': 'United States', 'city': 'Princeto...
#
#                               HourlyRate  AvgFeedbackScore  \
# 0  {'currencyCode': 'USD', 'amount': 60}          4.925208
# 1  {'currencyCode': 'USD', 'amount': 20}          4.675676
# 2  {'currencyCode': 'USD', 'amount': 65}          0.000000
#
#                LastActivity  TotalHoursBilled  TotalFeedbacks  \
# 0  2021-03-31T00:00:00.000Z       1861.333333              53
# 1  2021-04-03T00:00:00.000Z         23.000000               2
# 2  2021-04-03T00:00:00.000Z         10.000000               0
#
#    TotalPortfolioItems                                             Skills  \
# 0                   20  [{'skill': {'name': 'wordpress', 'prettyName':...
# 1                    1  [{'skill': {'name': 'social-media-content-crea...
# 2                    3  [{'skill': {'name': 'oracle-java-ee', 'prettyN...
#
#    RecentAvgFeedbackScore  RecentTotalFeedbacks  RecentHoursBilled  \
# 0                4.925208                     0         206.166667
# 1                4.675676                     2          14.000000
# 2                0.000000                     0          10.000000
#
#    TotalHourlyJobs  TotalFixedPriceJobs  CombinedTotalEarnings  \
# 0               58                   41               86694.88
# 1                5                    1                1143.00
# 2                1                    1                 292.50
#
#    CombinedRecentEarnings MemberSince
# 0                 9411.33    1-Aug-16
# 1                  507.60    3-Feb-19
# 2                  360.00   21-Jun-17

# %% [markdown]
# #### Checking the skewness of numerical columns of the data

# %% [markdown]
# #### Most of the variables shows right skewness because as we seen mean > median  so we have to apply transformation techniques to make our data normally distributed

# %%
Freelance_Data.describe()
# Out:
#        AvgFeedbackScore  TotalHoursBilled  TotalFeedbacks  \
# count       5823.000000       5823.000000     5823.000000
# mean           4.322840        652.333211       21.849219
# std            1.561695       1652.570875       52.635204
# min            0.000000          0.000000        0.000000
# 25%            4.771310         12.750000        2.000000
# 50%            4.973319        104.333333        6.000000
# 75%            5.000000        554.566667       19.000000
# max            5.000000      27455.303330     1413.000000
#
#        TotalPortfolioItems  RecentAvgFeedbackScore  RecentTotalFeedbacks  \
# count          5823.000000             5823.000000           5823.000000
# mean              3.680920                3.739324              2.974068
# std               6.935874                2.071487              5.664062
# min               0.000000                0.000000              0.000000
# 25%               0.000000                3.816864              0.000000
# 50%               1.000000                4.959588              1.000000
# 75%               5.000000                5.000000              3.000000
# max             156.000000                5.000000            130.000000
#
#        RecentHoursBilled  TotalHourlyJobs  TotalFixedPriceJobs  \
# count        5823.000000      5823.000000          5823.000000
# mean          110.208884        15.737421            22.589902
# std           237.551099        32.364804            63.301901
# min             0.000000         0.000000             0.000000
# 25%             0.000000         2.000000             1.500000
# 50%            17.000000         5.000000             5.000000
# 75%           109.833333        16.000000            16.000000
# max          3507.333333       697.000000          1640.000000
#
#        CombinedTotalEarnings  CombinedRecentEarnings
# count           5.236000e+03             5236.000000
# mean            4.006761e+04             6470.824975
# std             2.405826e+05            21687.601618
# min             0.000000e+00                0.000000
# 25%             1.108005e+03              157.777500
# 50%             6.250900e+03             1144.760000
# 75%             2.958792e+04             5444.500000
# max             1.125739e+07           737095.610000

# %% [markdown]
# ![seo-what-is-data-preparation_jnd1rl.webp](attachment:seo-what-is-data-preparation_jnd1rl.webp)

# %% [markdown]
# # Data Preparation :
# ##### " Most of the dataset is not in the standard format for our prediction so first we have to prepare to get better results "

# %% [markdown]
# #### We will Extract Different columns from the dataset to get better prediction results .

# %% [markdown]
# #### Get Location

# %%
Get_Location=[]
for i in Freelance_Data["Location"] :
    res = ast.literal_eval(i)
    Get_Location.append(res['city'])
Freelance_Data['City']=Get_Location

# %% [markdown]
# #### Get HourlyRate

# %%
Hourly_Rate=[]
for i in Freelance_Data["HourlyRate"] :
    res = ast.literal_eval(i)
    Hourly_Rate.append(res['amount'])
Freelance_Data['HourlyRateUsd']=Hourly_Rate

# %% [markdown]
# #### I am Extracting skills from the title Column

# %%
Freelance_Data=Freelance_Data[['Title', 'AvgFeedbackScore','TotalFeedbacks','RecentAvgFeedbackScore', 'RecentTotalFeedbacks','LastActivity',
       'TotalHoursBilled', 'TotalPortfolioItems', 'RecentHoursBilled',
       'TotalHourlyJobs', 'TotalFixedPriceJobs', 'CombinedTotalEarnings',
       'CombinedRecentEarnings', 'MemberSince', 'City', 'HourlyRateUsd']]

# %% [markdown]
# #### Remove Special Characters and Represent All the tile Characters in title format

# %%
Freelance_Data['Title e']= Freelance_Data['Title'].str.replace('\W', ' ')
Freelance_Data['Title e']=Freelance_Data['Title e'].str.title()
# Out:
# C:\Users\Zigron\AppData\Local\Temp\ipykernel_14408\2362614457.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Freelance_Data['Title e']= Freelance_Data['Title'].str.replace('\W', ' ')

# %% [markdown]
# #### I am using general skills Categories that are used to sell any freelancer skills in the market

# %%
skills_list=['Developer','Social Media','Solution Architect','Logistics','Videographer','Designer','Marketing','Seo',
             'Recruiter','Engineer','Networking','Accounting',' Writer','Bookkeeper','Content Creator','Translator',
            'Copywriter','Accountant','Data','Communications Specialist','Assistant','Consultant',
            'Marketing','Copy Editor','Engineer','Sales','Editor','Assistant','Content',
            'Talent Acquisition Professional','Design','Translation','Writer',
             'Virtual Host','Clinical','Leadership','People Skills','Business',
             'Development','Video Production','3D Animation','3D Modeling','Ecommerce','Finance',
             'Financial Modeling','Artist','Photographer','Technology','Project Manager','Accounts','Admin','Specialist','Tax Practioner','Programmer',
             'Blogger','Advertising','Event Planner','Marketer','Advisor','Zendesk Specialist','Content Creator',
            'Career Services','Website','Web Dev','Crm Experts','Partnerships','Ppc Expert','Customer Support','Analytics','Google Expert','Brand','Telemarketing','Private Investigator',
             'Adobe Suite','Research','Assistant','Customer Service','Expert Proofreader',
            'Operations Expert','Researcher','Financial Expert','Real Estate','Business',
            'Full Stack','Insurance Consulting']

skills=[]
mila=''
             
for i in Freelance_Data['Title e'] :
    mila=''
    for j in skills_list :
        if j in i :
            mila=j
            skills.append(j)
            break
            
    if len(mila)== 0 :
        skills.append(np.NaN)
            
Freelance_Data['Skills']=skills

# %% [markdown]
# ## Data Cleaning :

# %% [markdown]
# #### Dropping Null Values from the data

# %%
Freelance_Data=Freelance_Data.dropna()

# %%
Freelance_Data=Freelance_Data[['Skills', 'AvgFeedbackScore','TotalFeedbacks','RecentAvgFeedbackScore', 'RecentTotalFeedbacks','LastActivity',
       'TotalHoursBilled', 'TotalPortfolioItems', 'RecentHoursBilled',
       'TotalHourlyJobs', 'TotalFixedPriceJobs', 'CombinedTotalEarnings',
       'CombinedRecentEarnings', 'MemberSince', 'City', 'HourlyRateUsd']]

# %% [markdown]
# ## Data Analysis and Validation

# %% [markdown]
# #### As we seen in the pairplot the dataset is not shows a normal distribution

# %%
p=sns.pairplot(Freelance_Data)

# %% [markdown]
# #### Assumption 1 :
#
# ##### " Their is less linearity exsists between independent and dependent feature "

# %%
p=sns.pairplot(Freelance_Data, x_vars=['AvgFeedbackScore', 'TotalFeedbacks',
       'RecentAvgFeedbackScore', 'RecentTotalFeedbacks', 'TotalHoursBilled',
       'TotalPortfolioItems', 'RecentHoursBilled', 'TotalHourlyJobs',
       'TotalFixedPriceJobs', 'CombinedTotalEarnings',
       'CombinedRecentEarnings'], y_vars='HourlyRateUsd', size=3, aspect=0.6)
# Out:
# C:\Users\Zigron\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Finding Correlation

# %% [markdown]
# #### The Pearson correlation coefficient measures the linear association between variables. Its value can be interpreted like so:
#
# ###### +1 - Complete positive correlation
# ###### +0.8 - Strong positive correlation
# ###### +0.6 - Moderate positive correlation
# ###### 0 - no correlation whatsoever
# ###### -0.6 - Moderate negative correlation
# ###### -0.8 - Strong negative correlation
# ###### -1 - Complete negative correlation

# %% [markdown]
# #### Relation ship between input and output column the Pearson's correlation shows a very less or no assosiation between input and output features

# %%
# calculate the Pearson's correlation between two variables
for i in ['AvgFeedbackScore', 'TotalFeedbacks',
       'RecentAvgFeedbackScore', 'RecentTotalFeedbacks', 'TotalHoursBilled',
       'TotalPortfolioItems', 'RecentHoursBilled', 'TotalHourlyJobs',
       'TotalFixedPriceJobs', 'CombinedTotalEarnings',
       'CombinedRecentEarnings','HourlyRateUsd'] :
    data1 = Freelance_Data[i]
    data2 = Freelance_Data['HourlyRateUsd']
    corr, _ = pearsonr(data1, data2)
    print('Pearsons correlation ' + ' Between '+ i + ' and '+ 'HourlyRateUsd ' +' : ' + str(corr))
# Out:
# Pearsons correlation  Between AvgFeedbackScore and HourlyRateUsd  : 0.060504600318177934
# Pearsons correlation  Between TotalFeedbacks and HourlyRateUsd  : 0.05952422762693569
# Pearsons correlation  Between RecentAvgFeedbackScore and HourlyRateUsd  : 0.05843140415703177
# Pearsons correlation  Between RecentTotalFeedbacks and HourlyRateUsd  : 0.0013654996977038004
# Pearsons correlation  Between TotalHoursBilled and HourlyRateUsd  : 0.02784158903732555
# Pearsons correlation  Between TotalPortfolioItems and HourlyRateUsd  : 0.04057170292253185
# Pearsons correlation  Between RecentHoursBilled and HourlyRateUsd  : 0.029459793572233696
# Pearsons correlation  Between TotalHourlyJobs and HourlyRateUsd  : 0.11411862876492913
# Pearsons correlation  Between TotalFixedPriceJobs and HourlyRateUsd  : 0.02747222997878825
# Pearsons correlation  Between CombinedTotalEarnings and HourlyRateUsd  : 0.05684130469734067
# Pearsons correlation  Between CombinedRecentEarnings and HourlyRateUsd  : 0.13428093834900626
# Pearsons correlation  Between HourlyRateUsd and HourlyRateUsd  : 0.9999999999999996

# %% [markdown]
# #### Assumption 2 :
# ##### "Their is less correlation between idependent variables so no multicollinearity exsists as such"

# %% [markdown]
# #### Relationship between independent features

# %% [markdown]
# #### There is also no multicollineraity between independent features

# %%
corrmat = Freelance_Data.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True, annot=True, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# #### Assumption 3 :
# ##### "The number of observations are here is greater than the number of independent variables."

# %%
print('Total No of Rows are: {} and Total No of Columns are: {}'.format(Freelance_Data.shape[0],Freelance_Data.shape[1]))
# Out:
# Total No of Rows are: 4471 and Total No of Columns are: 16

# %% [markdown]
# ### Feature Engineering

# %%
Freelance_Data['LastActivity'] = pd.to_datetime(Freelance_Data['LastActivity'], errors='coerce')
Freelance_Data['MemberSince'] = pd.to_datetime(Freelance_Data['MemberSince'], errors='coerce')

# %%
Freelance_Data['LastActivityYear']=Freelance_Data['LastActivity'].dt.year
Freelance_Data['LastActivityMonth']=Freelance_Data['LastActivity'].dt.month
Freelance_Data['LastActivityDay']=Freelance_Data['LastActivity'].dt.day

# %%
Freelance_Data['MemberSinceYear'] = Freelance_Data['MemberSince'].dt.year
Freelance_Data['MemberSinceMonth'] = Freelance_Data['MemberSince'].dt.month
Freelance_Data['MemberSinceDay'] = Freelance_Data['MemberSince'].dt.day

# %%
Freelance_Data['TotalExpInTermsOfYear']=2022-Freelance_Data['MemberSince'].dt.year

# %%
Freelance_Data=Freelance_Data[['Skills', 'AvgFeedbackScore', 'TotalFeedbacks',
       'RecentAvgFeedbackScore', 'RecentTotalFeedbacks',
       'TotalHoursBilled', 'TotalPortfolioItems', 'RecentHoursBilled',
       'TotalHourlyJobs', 'TotalFixedPriceJobs', 'CombinedTotalEarnings',
       'CombinedRecentEarnings','City','LastActivityYear', 'LastActivityMonth', 'LastActivityDay',
       'MemberSinceYear', 'MemberSinceMonth', 'MemberSinceDay',
       'TotalExpInTermsOfYear','HourlyRateUsd']]

# %% [markdown]
# ### Data Prepocessing

# %% [markdown]
# #### There is No Null value in the data

# %%
Freelance_Data.isnull().sum()
# Out:
# Skills                    0
# AvgFeedbackScore          0
# TotalFeedbacks            0
# RecentAvgFeedbackScore    0
# RecentTotalFeedbacks      0
# TotalHoursBilled          0
# TotalPortfolioItems       0
# RecentHoursBilled         0
# TotalHourlyJobs           0
# TotalFixedPriceJobs       0
# CombinedTotalEarnings     0
# CombinedRecentEarnings    0
# City                      0
# LastActivityYear          0
# LastActivityMonth         0
# LastActivityDay           0
# MemberSinceYear           0
# MemberSinceMonth          0
# MemberSinceDay            0
# TotalExpInTermsOfYear     0
# HourlyRateUsd             0
# dtype: int64

# %% [markdown]
# #### One Hot Encoding
#
# ###### "It is a technique used to encode the categorical into numerical format "

# %%
Freelance_Data=pd.get_dummies(Freelance_Data, columns=["Skills", "City"], prefix=["Skill", "City"])

# %% [markdown]
# #### No of Rows and Columns in the dataset

# %%
print('Total No of Rows are: {} and Total No of Columns are: {}'.format(Freelance_Data.shape[0],Freelance_Data.shape[1]))
# Out:
# Total No of Rows are: 4471 and Total No of Columns are: 1446

# %%
x = Freelance_Data.drop(["HourlyRateUsd"],axis=1)
y = Freelance_Data.HourlyRateUsd

# %% [markdown]
# #### Standard Scaler
# ##### Applying Strandard Scaler to transform the data

# %%
sc = StandardScaler()
X = sc.fit_transform(x)

# %% [markdown]
# # Data Modelling and Results Interpretation

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state=5)
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)

# model evaluation for training set
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 44.665323052697424
# R2 score is 0.20848906958475444
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 1.6374321373226966e+16
# R2 score is -1.3805338297788016e+29

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(X_train,Y_train)
svr_y_pred = svr.predict(X_train)

print("The model performance for testing set")
print("--------------------------------------")
print("Accuracy: {}".format(svr.score(X_train,Y_train)))
print("R squared: {}".format(r2_score(y_true=Y_train,y_pred=svr_y_pred)))
# Out:
# The model performance for testing set
# --------------------------------------
# Accuracy: -0.008262872654025255
# R squared: -0.008262872654025255

# %% [markdown]
# ##### The Model do not show very good results in the testing phase because the R2 is  in negative direction

# %% [markdown]
# #### Assumption 4 :
# ##### "Residuals as we know are the differences between the true value and the predicted value. One of the assumptions of linear regression is that the mean of the residuals should be zero. So let's find out."

# %% [markdown]
# #### The mean value is very large because cause highly influence on the data

# %%
residuals = Y_test.values-y_test_predict
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals 531707434008803.2

# %% [markdown]
# #### Assumption 5:
# ##### "Homoscedasticity means that the residuals have equal or almost equal variance across the regression line. By plotting the error terms with predicted terms we can check that there should not be any pattern in the error terms"
#
# #### ----------------------
#
# #### Detecting heteroscedasticity! :
#
# ##### "Graphical Method: Firstly do the regression analysis and then plot the error terms against the predicted values( Yi^). If there is a definite pattern (like linear or quadratic or funnel shaped) obtained from the scatter plot then heteroscedasticity is present."

# %%
p = sns.scatterplot(y_test_predict,residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot([0,26],[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')
# Out:
# C:\Users\Zigron\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Zigron\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Now we will be applying tests. :
#
# ###### "if we want 95% confidence on our findings and tests then the p-value should be less than 0.05 to be able to reject the null hypothesis. Remember, a researcher or data scientist would always aim to reject the null hypothesis."

# %% [markdown]
# ##### Since p value is less than 0.05 in Goldfeld Quandt Test, we can reject it's null hypothesis that error terms are homoscedastic.

# %% [markdown]
# #### Goldfeld Quandt Test :
#
# ##### Checking heteroscedasticity : Using Goldfeld Quandt we test for heteroscedasticity.
#
# ###### Null Hypothesis: Error terms are homoscedastic
# ###### Alternative Hypothesis: Error terms are heteroscedastic.

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residuals, X_test)
print(lzip(name, test))
# Out:
# [('F statistic', 1.7176470623040692), ('p-value', 0.011485625530059818)]

# %% [markdown]
# #### Assumption No :6
#
# ##### "Error term will always have to show Normal Distribution"

# %%
p = sns.distplot(residuals,kde=True)
p = plt.title('Normality of error terms/residuals')
# Out:
# C:\Users\Zigron\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Assumption No : 7
# ##### "No autocorrelation exsists between the error terms in the data otherwise they cause distrubtion"

# %%
plt.figure(figsize=(10,5))
p = sns.lineplot(y_test_predict,residuals,marker='o',color='blue')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot([0,26],[0,0],color='red')
p = plt.title('Residuals vs fitted values plot for autocorrelation check')
# Out:
# C:\Users\Zigron\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Zigron\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Checking for autocorrelation To ensure the absence of autocorrelation we use Ljungbox test.
#
# ##### Null Hypothesis: Autocorrelation is absent.
#
# ##### Alternative Hypothesis: Autocorrelation is present.

# %%
from statsmodels.stats import diagnostic as diag
print('Autocorrelation is absent :',min(np.array(diag.acorr_ljungbox(residuals , lags = 40)['lb_pvalue'])))
# Out:
# Autocorrelation is absent : 0.1042451263071411

# %% [markdown]
# # Select Minimum and Maximum Price Range

# %% [markdown]
# ##### Given a Range of prices to freelancer we can set a treshhold to offer them a best price to work with client by taking their given rate and multiply with theshhold to give them a minimum and maximum price range to work.

# %% [markdown]
# ### For Example we set a threshhold of 10% and you have a right to select the price range you want for specific category we select price <=5000.

# %%
price_Range=5000
for i in y_test_predict :
    if i > 0 and i <=price_Range:
        print('You can offer a Price Range Between',i-i*0.10,'and' ,i*0.10+i,'To this Freelancer')
        
    else :
        continue
# Out:
# You can offer a Price Range Between 63.196875 and 77.240625 To this Freelancer
# You can offer a Price Range Between 107.353125 and 131.209375 To this Freelancer
# You can offer a Price Range Between 50.990625 and 62.321875 To this Freelancer
# You can offer a Price Range Between 3.796875 and 4.640625 To this Freelancer
# You can offer a Price Range Between 54.703125 and 66.859375 To this Freelancer
# You can offer a Price Range Between 38.165625 and 46.646875 To this Freelancer
# You can offer a Price Range Between 50.315625 and 61.496875 To this Freelancer
# You can offer a Price Range Between 63.1125 and 77.1375 To this Freelancer
# You can offer a Price Range Between 24.103125 and 29.459375 To this Freelancer
# You can offer a Price Range Between 12.515625 and 15.296875 To this Freelancer
# You can offer a Price Range Between 63.8015625 and 77.9796875 To this Freelancer
# You can offer a Price Range Between 17.803125 and 21.759375 To this Freelancer
# You can offer a Price Range Between 88.5375 and 108.2125 To this Freelancer
# You can offer a Price Range Between 19.378125 and 23.684375 To this Freelancer
# You can offer a Price Range Between 32.934375 and 40.253125 To this Freelancer
# You can offer a Price Range Between 62.04375 and 75.83125 To this Freelancer
# You can offer a Price Range Between 46.940625 and 57.371875 To this Freelancer
# You can offer a Price Range Between 77.034375 and 94.153125 To this Freelancer
# You can offer a Price Range Between 32.034375 and 39.153125 To this Freelancer
# You can offer a Price Range Between 40.078125 and 48.984375 To this Freelancer
# You can offer a Price Range Between 16.003125 and 19.559375 To this Freelancer
# You can offer a Price Range Between 175.6125 and 214.6375 To this Freelancer
# You can offer a Price Range Between 45.759375 and 55.928125 To this Freelancer
# You can offer a Price Range Between 47.446875 and 57.990625 To this Freelancer
# You can offer a Price Range Between 38.053125 and 46.509375 To this Freelancer
# You can offer a Price Range Between 67.978125 and 83.084375 To this Freelancer
# You can offer a Price Range Between 38.390625 and 46.921875 To this Freelancer
# You can offer a Price Range Between 73.940625 and 90.371875 To this Freelancer
# You can offer a Price Range Between 76.753125 and 93.809375 To this Freelancer
# You can offer a Price Range Between 49.415625 and 60.396875 To this Freelancer
# You can offer a Price Range Between 25.903125 and 31.659375 To this Freelancer
# You can offer a Price Range Between 11.728125 and 14.334375 To this Freelancer
# You can offer a Price Range Between 15.440625 and 18.871875 To this Freelancer
# You can offer a Price Range Between 46.546875 and 56.890625 To this Freelancer
# You can offer a Price Range Between 56.390625 and 68.921875 To this Freelancer
# You can offer a Price Range Between 28.378125 and 34.684375 To this Freelancer
# You can offer a Price Range Between 6.778125 and 8.284375 To this Freelancer
# You can offer a Price Range Between 20.390625 and 24.921875 To this Freelancer
# You can offer a Price Range Between 51.103125 and 62.459375 To this Freelancer
# You can offer a Price Range Between 88.903125 and 108.659375 To this Freelancer
# You can offer a Price Range Between 39.290625 and 48.021875 To this Freelancer
# You can offer a Price Range Between 70.115625 and 85.696875 To this Freelancer
# You can offer a Price Range Between 101.278125 and 123.784375 To this Freelancer
# You can offer a Price Range Between 38.053125 and 46.509375 To this Freelancer
# You can offer a Price Range Between 47.390625 and 57.921875 To this Freelancer
# You can offer a Price Range Between 68.709375 and 83.978125 To this Freelancer
# You can offer a Price Range Between 51.8203125 and 63.3359375 To this Freelancer
# You can offer a Price Range Between 16.790625 and 20.521875 To this Freelancer
# You can offer a Price Range Between 62.071875 and 75.865625 To this Freelancer
# You can offer a Price Range Between 67.246875 and 82.190625 To this Freelancer
# You can offer a Price Range Between 54.928125 and 67.134375 To this Freelancer
# You can offer a Price Range Between 12.796875 and 15.640625 To this Freelancer
# You can offer a Price Range Between 51.328125 and 62.734375 To this Freelancer
# You can offer a Price Range Between 55.096875 and 67.340625 To this Freelancer
# You can offer a Price Range Between 100.490625 and 122.821875 To this Freelancer
# You can offer a Price Range Between 24.890625 and 30.421875 To this Freelancer
# You can offer a Price Range Between 35.128125 and 42.934375 To this Freelancer
# You can offer a Price Range Between 122.315625 and 149.496875 To this Freelancer
# You can offer a Price Range Between 60.553125 and 74.009375 To this Freelancer
# You can offer a Price Range Between 35.071875 and 42.865625 To this Freelancer
# You can offer a Price Range Between 10.040625 and 12.271875 To this Freelancer
# You can offer a Price Range Between 43.340625 and 52.971875 To this Freelancer
# You can offer a Price Range Between 73.434375 and 89.753125 To this Freelancer
# You can offer a Price Range Between 57.234375 and 69.953125 To this Freelancer
# You can offer a Price Range Between 43.453125 and 53.109375 To this Freelancer
# You can offer a Price Range Between 19.040625 and 23.271875 To this Freelancer
# You can offer a Price Range Between 38.925 and 47.575 To this Freelancer
# You can offer a Price Range Between 70.003125 and 85.559375 To this Freelancer
# You can offer a Price Range Between 91.603125 and 111.959375 To this Freelancer
# You can offer a Price Range Between 69.271875 and 84.665625 To this Freelancer
# You can offer a Price Range Between 69.24375 and 84.63125 To this Freelancer
# You can offer a Price Range Between 33.159375 and 40.528125 To this Freelancer
# You can offer a Price Range Between 110.503125 and 135.059375 To this Freelancer
# You can offer a Price Range Between 32.540625 and 39.771875 To this Freelancer
# You can offer a Price Range Between 50.934375 and 62.253125 To this Freelancer
# You can offer a Price Range Between 117.928125 and 144.134375 To this Freelancer
# You can offer a Price Range Between 77.315625 and 94.496875 To this Freelancer
# You can offer a Price Range Between 93.121875 and 113.815625 To this Freelancer
# You can offer a Price Range Between 27.703125 and 33.859375 To this Freelancer
# You can offer a Price Range Between 54.871875 and 67.065625 To this Freelancer
# You can offer a Price Range Between 34.340625 and 41.971875 To this Freelancer
# You can offer a Price Range Between 55.378125 and 67.684375 To this Freelancer
# You can offer a Price Range Between 16.565625 and 20.246875 To this Freelancer
# You can offer a Price Range Between 53.690625 and 65.621875 To this Freelancer
# You can offer a Price Range Between 6.328125 and 7.734375 To this Freelancer
# You can offer a Price Range Between 34.228125 and 41.834375 To this Freelancer
# You can offer a Price Range Between 123.440625 and 150.871875 To this Freelancer
# You can offer a Price Range Between 21.740625 and 26.571875 To this Freelancer
# You can offer a Price Range Between 29.5734375 and 36.1453125 To this Freelancer
# You can offer a Price Range Between 30.178125 and 36.884375 To this Freelancer
# You can offer a Price Range Between 74.053125 and 90.509375 To this Freelancer
# You can offer a Price Range Between 36.39375 and 44.48125 To this Freelancer
# You can offer a Price Range Between 105.665625 and 129.146875 To this Freelancer
# You can offer a Price Range Between 5.6390625 and 6.8921875 To this Freelancer
# You can offer a Price Range Between 62.803125 and 76.759375 To this Freelancer
# You can offer a Price Range Between 63.815625 and 77.996875 To this Freelancer
# You can offer a Price Range Between 52.846875 and 64.590625 To this Freelancer
# You can offer a Price Range Between 67.190625 and 82.121875 To this Freelancer
# You can offer a Price Range Between 31.640625 and 38.671875 To this Freelancer
# You can offer a Price Range Between 8.634375 and 10.553125 To this Freelancer
# You can offer a Price Range Between 22.809375 and 27.878125 To this Freelancer
# You can offer a Price Range Between 16.4390625 and 20.0921875 To this Freelancer
# You can offer a Price Range Between 17.915625 and 21.896875 To this Freelancer
# You can offer a Price Range Between 45.478125 and 55.584375 To this Freelancer
# You can offer a Price Range Between 7.396875 and 9.040625 To this Freelancer
# You can offer a Price Range Between 39.54375 and 48.33125 To this Freelancer
# You can offer a Price Range Between 66.853125 and 81.709375 To this Freelancer
# You can offer a Price Range Between 33.6234375 and 41.0953125 To this Freelancer
# You can offer a Price Range Between 29.953125 and 36.609375 To this Freelancer
# You can offer a Price Range Between 146.053125 and 178.509375 To this Freelancer
# You can offer a Price Range Between 7.565625 and 9.246875 To this Freelancer
# You can offer a Price Range Between 111.2203125 and 135.9359375 To this Freelancer
# You can offer a Price Range Between 42.721875 and 52.215625 To this Freelancer
# You can offer a Price Range Between 162.421875 and 198.515625 To this Freelancer
# You can offer a Price Range Between 31.978125 and 39.084375 To this Freelancer
# You can offer a Price Range Between 123.440625 and 150.871875 To this Freelancer
# You can offer a Price Range Between 95.090625 and 116.221875 To this Freelancer
# You can offer a Price Range Between 70.565625 and 86.246875 To this Freelancer
# You can offer a Price Range Between 46.0125 and 56.2375 To this Freelancer
# You can offer a Price Range Between 46.884375 and 57.303125 To this Freelancer
# You can offer a Price Range Between 49.190625 and 60.121875 To this Freelancer
# You can offer a Price Range Between 5.371875 and 6.565625 To this Freelancer
# You can offer a Price Range Between 109.85625 and 134.26875 To this Freelancer
# You can offer a Price Range Between 65.390625 and 79.921875 To this Freelancer
# You can offer a Price Range Between 112.415625 and 137.396875 To this Freelancer
# You can offer a Price Range Between 28.4484375 and 34.7703125 To this Freelancer
# You can offer a Price Range Between 67.9640625 and 83.0671875 To this Freelancer
# You can offer a Price Range Between 7.959375 and 9.728125 To this Freelancer
# You can offer a Price Range Between 34.115625 and 41.696875 To this Freelancer
# You can offer a Price Range Between 73.940625 and 90.371875 To this Freelancer
# You can offer a Price Range Between 69.384375 and 84.803125 To this Freelancer
# You can offer a Price Range Between 49.528125 and 60.534375 To this Freelancer
# You can offer a Price Range Between 6.271875 and 7.665625 To this Freelancer
# You can offer a Price Range Between 44.803125 and 54.759375 To this Freelancer
# You can offer a Price Range Between 41.878125 and 51.184375 To this Freelancer
# You can offer a Price Range Between 22.3171875 and 27.2765625 To this Freelancer
# You can offer a Price Range Between 43.621875 and 53.315625 To this Freelancer
# You can offer a Price Range Between 24.103125 and 29.459375 To this Freelancer
# You can offer a Price Range Between 127.5609375 and 155.9078125 To this Freelancer
# You can offer a Price Range Between 67.584375 and 82.603125 To this Freelancer
# You can offer a Price Range Between 20.953125 and 25.609375 To this Freelancer
# You can offer a Price Range Between 57.515625 and 70.296875 To this Freelancer
# You can offer a Price Range Between 107.353125 and 131.209375 To this Freelancer
# You can offer a Price Range Between 98.071875 and 119.865625 To this Freelancer
# You can offer a Price Range Between 64.940625 and 79.371875 To this Freelancer
# You can offer a Price Range Between 79.3125 and 96.9375 To this Freelancer
# You can offer a Price Range Between 99.61875 and 121.75625 To this Freelancer
# You can offer a Price Range Between 15.665625 and 19.146875 To this Freelancer
# You can offer a Price Range Between 33.103125 and 40.459375 To this Freelancer
# You can offer a Price Range Between 52.5375 and 64.2125 To this Freelancer
# You can offer a Price Range Between 58.9640625 and 72.0671875 To this Freelancer
# You can offer a Price Range Between 87.215625 and 106.596875 To this Freelancer
# You can offer a Price Range Between 1.040625 and 1.271875 To this Freelancer
# You can offer a Price Range Between 78.665625 and 96.146875 To this Freelancer
# You can offer a Price Range Between 58.7109375 and 71.7578125 To this Freelancer
# You can offer a Price Range Between 24.778125 and 30.284375 To this Freelancer
# You can offer a Price Range Between 138.740625 and 169.571875 To this Freelancer
# You can offer a Price Range Between 28.40625 and 34.71875 To this Freelancer
# You can offer a Price Range Between 76.303125 and 93.259375 To this Freelancer
# You can offer a Price Range Between 71.803125 and 87.759375 To this Freelancer
# You can offer a Price Range Between 26.128125 and 31.934375 To this Freelancer
# You can offer a Price Range Between 130.640625 and 159.671875 To this Freelancer
# You can offer a Price Range Between 102.965625 and 125.846875 To this Freelancer
# You can offer a Price Range Between 35.015625 and 42.796875 To this Freelancer
# You can offer a Price Range Between 39.6 and 48.4 To this Freelancer
# You can offer a Price Range Between 14.203125 and 17.359375 To this Freelancer
# You can offer a Price Range Between 23.090625 and 28.221875 To this Freelancer
# You can offer a Price Range Between 33.046875 and 40.390625 To this Freelancer
# You can offer a Price Range Between 29.053125 and 35.509375 To this Freelancer
# You can offer a Price Range Between 49.696875 and 60.740625 To this Freelancer
# You can offer a Price Range Between 69.384375 and 84.803125 To this Freelancer
# You can offer a Price Range Between 68.259375 and 83.428125 To this Freelancer
# You can offer a Price Range Between 56.615625 and 69.196875 To this Freelancer
# You can offer a Price Range Between 46.828125 and 57.234375 To this Freelancer
# You can offer a Price Range Between 56.784375 and 69.403125 To this Freelancer
# You can offer a Price Range Between 58.528125 and 71.534375 To this Freelancer
# You can offer a Price Range Between 95.4703125 and 116.6859375 To this Freelancer
# You can offer a Price Range Between 72.590625 and 88.721875 To this Freelancer
# You can offer a Price Range Between 47.953125 and 58.609375 To this Freelancer
# You can offer a Price Range Between 33.496875 and 40.940625 To this Freelancer
# You can offer a Price Range Between 20.278125 and 24.784375 To this Freelancer
# You can offer a Price Range Between 46.715625 and 57.096875 To this Freelancer
# You can offer a Price Range Between 98.690625 and 120.621875 To this Freelancer
# You can offer a Price Range Between 58.246875 and 71.190625 To this Freelancer
# You can offer a Price Range Between 35.83125 and 43.79375 To this Freelancer
# You can offer a Price Range Between 43.228125 and 52.834375 To this Freelancer
# You can offer a Price Range Between 108.478125 and 132.584375 To this Freelancer
# You can offer a Price Range Between 50.428125 and 61.634375 To this Freelancer
# You can offer a Price Range Between 16.678125 and 20.384375 To this Freelancer
# You can offer a Price Range Between 68.878125 and 84.184375 To this Freelancer
# You can offer a Price Range Between 57.346875 and 70.090625 To this Freelancer
# You can offer a Price Range Between 48.740625 and 59.571875 To this Freelancer
# You can offer a Price Range Between 22.10625 and 27.01875 To this Freelancer
# You can offer a Price Range Between 106.453125 and 130.109375 To this Freelancer
# You can offer a Price Range Between 149.878125 and 183.184375 To this Freelancer
# You can offer a Price Range Between 46.040625 and 56.271875 To this Freelancer
# You can offer a Price Range Between 48.178125 and 58.884375 To this Freelancer
# You can offer a Price Range Between 41.878125 and 51.184375 To this Freelancer
# You can offer a Price Range Between 20.390625 and 24.921875 To this Freelancer
# You can offer a Price Range Between 73.828125 and 90.234375 To this Freelancer
# You can offer a Price Range Between 67.753125 and 82.809375 To this Freelancer
# You can offer a Price Range Between 34.959375 and 42.728125 To this Freelancer
# You can offer a Price Range Between 43.48125 and 53.14375 To this Freelancer
# You can offer a Price Range Between 25.453125 and 31.109375 To this Freelancer
# You can offer a Price Range Between 128.165625 and 156.646875 To this Freelancer
# You can offer a Price Range Between 5.175 and 6.325 To this Freelancer
# You can offer a Price Range Between 76.6265625 and 93.6546875 To this Freelancer
# You can offer a Price Range Between 82.51875 and 100.85625 To this Freelancer
# You can offer a Price Range Between 88.453125 and 108.109375 To this Freelancer
# You can offer a Price Range Between 53.4515625 and 65.3296875 To this Freelancer
# You can offer a Price Range Between 71.746875 and 87.690625 To this Freelancer
# You can offer a Price Range Between 105.890625 and 129.421875 To this Freelancer
# You can offer a Price Range Between 49.753125 and 60.809375 To this Freelancer
# You can offer a Price Range Between 51.046875 and 62.390625 To this Freelancer
# You can offer a Price Range Between 48.853125 and 59.709375 To this Freelancer
# You can offer a Price Range Between 15.553125 and 19.009375 To this Freelancer
# You can offer a Price Range Between 57.740625 and 70.571875 To this Freelancer
# You can offer a Price Range Between 42.328125 and 51.734375 To this Freelancer
# You can offer a Price Range Between 44.9859375 and 54.9828125 To this Freelancer
# You can offer a Price Range Between 48.459375 and 59.228125 To this Freelancer
# You can offer a Price Range Between 63.028125 and 77.034375 To this Freelancer
# You can offer a Price Range Between 54.140625 and 66.171875 To this Freelancer
# You can offer a Price Range Between 40.753125 and 49.809375 To this Freelancer
# You can offer a Price Range Between 65.728125 and 80.334375 To this Freelancer
# You can offer a Price Range Between 66.346875 and 81.090625 To this Freelancer
# You can offer a Price Range Between 99.028125 and 121.034375 To this Freelancer
# You can offer a Price Range Between 87.553125 and 107.009375 To this Freelancer
# You can offer a Price Range Between 30.965625 and 37.846875 To this Freelancer
# You can offer a Price Range Between 45.196875 and 55.240625 To this Freelancer
# You can offer a Price Range Between 52.509375 and 64.178125 To this Freelancer
# You can offer a Price Range Between 107.128125 and 130.934375 To this Freelancer
# You can offer a Price Range Between 52.340625 and 63.971875 To this Freelancer
# You can offer a Price Range Between 82.51875 and 100.85625 To this Freelancer
# You can offer a Price Range Between 28.040625 and 34.271875 To this Freelancer
# You can offer a Price Range Between 40.078125 and 48.984375 To this Freelancer
# You can offer a Price Range Between 79.790625 and 97.521875 To this Freelancer
# You can offer a Price Range Between 10.603125 and 12.959375 To this Freelancer
# You can offer a Price Range Between 58.246875 and 71.190625 To this Freelancer
# You can offer a Price Range Between 82.828125 and 101.234375 To this Freelancer
# You can offer a Price Range Between 38.728125 and 47.334375 To this Freelancer
# You can offer a Price Range Between 28.715625 and 35.096875 To this Freelancer
# You can offer a Price Range Between 41.371875 and 50.565625 To this Freelancer
# You can offer a Price Range Between 65.053125 and 79.509375 To this Freelancer
# You can offer a Price Range Between 39.54375 and 48.33125 To this Freelancer
# You can offer a Price Range Between 10.2515625 and 12.5296875 To this Freelancer
# You can offer a Price Range Between 23.878125 and 29.184375 To this Freelancer
# You can offer a Price Range Between 175.6125 and 214.6375 To this Freelancer
# You can offer a Price Range Between 29.953125 and 36.609375 To this Freelancer
# You can offer a Price Range Between 33.215625 and 40.596875 To this Freelancer
# You can offer a Price Range Between 52.14375 and 63.73125 To this Freelancer
# You can offer a Price Range Between 82.828125 and 101.234375 To this Freelancer
# You can offer a Price Range Between 8.353125 and 10.209375 To this Freelancer
# You can offer a Price Range Between 38.728125 and 47.334375 To this Freelancer
# You can offer a Price Range Between 59.090625 and 72.221875 To this Freelancer
# You can offer a Price Range Between 40.809375 and 49.878125 To this Freelancer
# You can offer a Price Range Between 27.309375 and 33.378125 To this Freelancer
# You can offer a Price Range Between 18.196875 and 22.240625 To this Freelancer
# You can offer a Price Range Between 5.484375 and 6.703125 To this Freelancer
# You can offer a Price Range Between 40.696875 and 49.740625 To this Freelancer
# You can offer a Price Range Between 0.984375 and 1.203125 To this Freelancer
# You can offer a Price Range Between 54.028125 and 66.034375 To this Freelancer
# You can offer a Price Range Between 28.378125 and 34.684375 To this Freelancer
# You can offer a Price Range Between 84.853125 and 103.709375 To this Freelancer
# You can offer a Price Range Between 70.5375 and 86.2125 To this Freelancer
# You can offer a Price Range Between 13.415625 and 16.396875 To this Freelancer
# You can offer a Price Range Between 28.603125 and 34.959375 To this Freelancer
# You can offer a Price Range Between 54.028125 and 66.034375 To this Freelancer
# You can offer a Price Range Between 39.43125 and 48.19375 To this Freelancer
# You can offer a Price Range Between 54.928125 and 67.134375 To this Freelancer
# You can offer a Price Range Between 80.353125 and 98.209375 To this Freelancer
# You can offer a Price Range Between 34.003125 and 41.559375 To this Freelancer
# You can offer a Price Range Between 35.015625 and 42.796875 To this Freelancer
# You can offer a Price Range Between 30.628125 and 37.434375 To this Freelancer
# You can offer a Price Range Between 51.8203125 and 63.3359375 To this Freelancer
# You can offer a Price Range Between 48.290625 and 59.021875 To this Freelancer
# You can offer a Price Range Between 62.803125 and 76.759375 To this Freelancer
# You can offer a Price Range Between 94.921875 and 116.015625 To this Freelancer
# You can offer a Price Range Between 69.778125 and 85.284375 To this Freelancer
# You can offer a Price Range Between 75.7546875 and 92.5890625 To this Freelancer
# You can offer a Price Range Between 19.209375 and 23.478125 To this Freelancer
# You can offer a Price Range Between 51.103125 and 62.459375 To this Freelancer
# You can offer a Price Range Between 61.565625 and 75.246875 To this Freelancer
# You can offer a Price Range Between 50.9484375 and 62.2703125 To this Freelancer
# You can offer a Price Range Between 81.028125 and 99.034375 To this Freelancer
# You can offer a Price Range Between 77.878125 and 95.184375 To this Freelancer
# You can offer a Price Range Between 57.628125 and 70.434375 To this Freelancer
# You can offer a Price Range Between 46.603125 and 56.959375 To this Freelancer
# You can offer a Price Range Between 58.078125 and 70.984375 To this Freelancer
# You can offer a Price Range Between 89.578125 and 109.484375 To this Freelancer
# You can offer a Price Range Between 44.915625 and 54.896875 To this Freelancer
# You can offer a Price Range Between 35.634375 and 43.553125 To this Freelancer
# You can offer a Price Range Between 53.184375 and 65.003125 To this Freelancer
# You can offer a Price Range Between 38.503125 and 47.059375 To this Freelancer
# You can offer a Price Range Between 38.7 and 47.3 To this Freelancer
# You can offer a Price Range Between 28.040625 and 34.271875 To this Freelancer
# You can offer a Price Range Between 22.303125 and 27.259375 To this Freelancer
# You can offer a Price Range Between 138.740625 and 169.571875 To this Freelancer
# You can offer a Price Range Between 51.778125 and 63.284375 To this Freelancer
# You can offer a Price Range Between 43.453125 and 53.109375 To this Freelancer
# You can offer a Price Range Between 16.678125 and 20.384375 To this Freelancer
# You can offer a Price Range Between 35.859375 and 43.828125 To this Freelancer
# You can offer a Price Range Between 86.203125 and 105.359375 To this Freelancer
# You can offer a Price Range Between 89.578125 and 109.484375 To this Freelancer
# You can offer a Price Range Between 87.13125 and 106.49375 To this Freelancer
# You can offer a Price Range Between 49.865625 and 60.946875 To this Freelancer
# You can offer a Price Range Between 31.978125 and 39.084375 To this Freelancer
# You can offer a Price Range Between 32.540625 and 39.771875 To this Freelancer
# You can offer a Price Range Between 36.421875 and 44.515625 To this Freelancer
# You can offer a Price Range Between 67.303125 and 82.259375 To this Freelancer
# You can offer a Price Range Between 44.071875 and 53.865625 To this Freelancer
# You can offer a Price Range Between 43.340625 and 52.971875 To this Freelancer
# You can offer a Price Range Between 69.946875 and 85.490625 To this Freelancer
# You can offer a Price Range Between 72.4921875 and 88.6015625 To this Freelancer
# You can offer a Price Range Between 115.340625 and 140.971875 To this Freelancer
# You can offer a Price Range Between 80.915625 and 98.896875 To this Freelancer
# You can offer a Price Range Between 49.978125 and 61.084375 To this Freelancer
# You can offer a Price Range Between 79.678125 and 97.384375 To this Freelancer
# You can offer a Price Range Between 117.928125 and 144.134375 To this Freelancer
# You can offer a Price Range Between 16.228125 and 19.834375 To this Freelancer
# You can offer a Price Range Between 73.715625 and 90.096875 To this Freelancer
# You can offer a Price Range Between 15.91875 and 19.45625 To this Freelancer
# You can offer a Price Range Between 76.303125 and 93.259375 To this Freelancer
# You can offer a Price Range Between 47.053125 and 57.509375 To this Freelancer
# You can offer a Price Range Between 22.134375 and 27.053125 To this Freelancer
# You can offer a Price Range Between 24.553125 and 30.009375 To this Freelancer
# You can offer a Price Range Between 69.103125 and 84.459375 To this Freelancer
# You can offer a Price Range Between 62.128125 and 75.934375 To this Freelancer
# You can offer a Price Range Between 32.203125 and 39.359375 To this Freelancer
# You can offer a Price Range Between 61.003125 and 74.559375 To this Freelancer
# You can offer a Price Range Between 164.503125 and 201.059375 To this Freelancer
# You can offer a Price Range Between 56.109375 and 68.578125 To this Freelancer
# You can offer a Price Range Between 53.353125 and 65.209375 To this Freelancer
# You can offer a Price Range Between 31.753125 and 38.809375 To this Freelancer
# You can offer a Price Range Between 14.625 and 17.875 To this Freelancer
# You can offer a Price Range Between 62.296875 and 76.140625 To this Freelancer
# You can offer a Price Range Between 32.315625 and 39.496875 To this Freelancer
# You can offer a Price Range Between 67.190625 and 82.121875 To this Freelancer
# You can offer a Price Range Between 53.015625 and 64.796875 To this Freelancer
# You can offer a Price Range Between 57.234375 and 69.953125 To this Freelancer
# You can offer a Price Range Between 60.890625 and 74.421875 To this Freelancer
# You can offer a Price Range Between 80.353125 and 98.209375 To this Freelancer
# You can offer a Price Range Between 69.159375 and 84.528125 To this Freelancer
# You can offer a Price Range Between 76.6265625 and 93.6546875 To this Freelancer
# You can offer a Price Range Between 36.4921875 and 44.6015625 To this Freelancer
# You can offer a Price Range Between 29.728125 and 36.334375 To this Freelancer
# You can offer a Price Range Between 43.903125 and 53.659375 To this Freelancer
# You can offer a Price Range Between 36.815625 and 44.996875 To this Freelancer
# You can offer a Price Range Between 97.171875 and 118.765625 To this Freelancer
# You can offer a Price Range Between 8.634375 and 10.553125 To this Freelancer
# You can offer a Price Range Between 37.209375 and 45.478125 To this Freelancer
# You can offer a Price Range Between 65.728125 and 80.334375 To this Freelancer
# You can offer a Price Range Between 95.990625 and 117.321875 To this Freelancer
# You can offer a Price Range Between 66.121875 and 80.815625 To this Freelancer
# You can offer a Price Range Between 75.290625 and 92.021875 To this Freelancer
# You can offer a Price Range Between 93.571875 and 114.365625 To this Freelancer
# You can offer a Price Range Between 87.8203125 and 107.3359375 To this Freelancer
# You can offer a Price Range Between 77.540625 and 94.771875 To this Freelancer
# You can offer a Price Range Between 50.934375 and 62.253125 To this Freelancer
# You can offer a Price Range Between 12.853125 and 15.709375 To this Freelancer
# You can offer a Price Range Between 64.265625 and 78.546875 To this Freelancer
# You can offer a Price Range Between 33.890625 and 41.421875 To this Freelancer
# You can offer a Price Range Between 94.415625 and 115.396875 To this Freelancer
# You can offer a Price Range Between 43.621875 and 53.315625 To this Freelancer
# You can offer a Price Range Between 62.128125 and 75.934375 To this Freelancer
# You can offer a Price Range Between 62.634375 and 76.553125 To this Freelancer
# You can offer a Price Range Between 35.465625 and 43.346875 To this Freelancer
# You can offer a Price Range Between 55.603125 and 67.959375 To this Freelancer
# You can offer a Price Range Between 82.040625 and 100.271875 To this Freelancer
# You can offer a Price Range Between 55.828125 and 68.234375 To this Freelancer
# You can offer a Price Range Between 30.628125 and 37.434375 To this Freelancer
# You can offer a Price Range Between 71.240625 and 87.071875 To this Freelancer
# You can offer a Price Range Between 67.753125 and 82.809375 To this Freelancer
# You can offer a Price Range Between 30.740625 and 37.571875 To this Freelancer
# You can offer a Price Range Between 75.4171875 and 92.1765625 To this Freelancer
# You can offer a Price Range Between 25.284375 and 30.903125 To this Freelancer
# You can offer a Price Range Between 132.328125 and 161.734375 To this Freelancer
# You can offer a Price Range Between 63.478125 and 77.584375 To this Freelancer
# You can offer a Price Range Between 65.728125 and 80.334375 To this Freelancer
# You can offer a Price Range Between 95.709375 and 116.978125 To this Freelancer
# You can offer a Price Range Between 31.471875 and 38.465625 To this Freelancer
# You can offer a Price Range Between 27.928125 and 34.134375 To this Freelancer
# You can offer a Price Range Between 42.975 and 52.525 To this Freelancer
# You can offer a Price Range Between 45.253125 and 55.309375 To this Freelancer
# You can offer a Price Range Between 62.04375 and 75.83125 To this Freelancer
# You can offer a Price Range Between 64.153125 and 78.409375 To this Freelancer
# You can offer a Price Range Between 52.790625 and 64.521875 To this Freelancer
# You can offer a Price Range Between 57.9375 and 70.8125 To this Freelancer
# You can offer a Price Range Between 90.590625 and 110.721875 To this Freelancer
# You can offer a Price Range Between 69.215625 and 84.596875 To this Freelancer
# You can offer a Price Range Between 27.253125 and 33.309375 To this Freelancer
# You can offer a Price Range Between 38.7 and 47.3 To this Freelancer
# You can offer a Price Range Between 25.228125 and 30.834375 To this Freelancer
# You can offer a Price Range Between 16.171875 and 19.765625 To this Freelancer
# You can offer a Price Range Between 37.940625 and 46.371875 To this Freelancer
# You can offer a Price Range Between 65.671875 and 80.265625 To this Freelancer
# You can offer a Price Range Between 55.265625 and 67.546875 To this Freelancer
# You can offer a Price Range Between 1.940625 and 2.371875 To this Freelancer
# You can offer a Price Range Between 62.071875 and 75.865625 To this Freelancer
# You can offer a Price Range Between 45.646875 and 55.790625 To this Freelancer
# You can offer a Price Range Between 18.253125 and 22.309375 To this Freelancer
# You can offer a Price Range Between 44.353125 and 54.209375 To this Freelancer
# You can offer a Price Range Between 130.190625 and 159.121875 To this Freelancer
# You can offer a Price Range Between 80.71875 and 98.65625 To this Freelancer
# You can offer a Price Range Between 77.653125 and 94.909375 To this Freelancer
# You can offer a Price Range Between 72.253125 and 88.309375 To this Freelancer
# You can offer a Price Range Between 19.378125 and 23.684375 To this Freelancer
# You can offer a Price Range Between 13.584375 and 16.603125 To this Freelancer
# You can offer a Price Range Between 52.565625 and 64.246875 To this Freelancer
# You can offer a Price Range Between 50.428125 and 61.634375 To this Freelancer
# You can offer a Price Range Between 102.403125 and 125.159375 To this Freelancer
# You can offer a Price Range Between 48.88125 and 59.74375 To this Freelancer
# You can offer a Price Range Between 140.146875 and 171.290625 To this Freelancer
# You can offer a Price Range Between 72.028125 and 88.034375 To this Freelancer
# You can offer a Price Range Between 72.590625 and 88.721875 To this Freelancer
# You can offer a Price Range Between 42.665625 and 52.146875 To this Freelancer
# You can offer a Price Range Between 128.165625 and 156.646875 To this Freelancer
# You can offer a Price Range Between 50.821875 and 62.115625 To this Freelancer
# You can offer a Price Range Between 19.040625 and 23.271875 To this Freelancer
# You can offer a Price Range Between 1.378125 and 1.684375 To this Freelancer
# You can offer a Price Range Between 70.171875 and 85.765625 To this Freelancer
# You can offer a Price Range Between 49.5 and 60.5 To this Freelancer
# You can offer a Price Range Between 36.365625 and 44.446875 To this Freelancer
# You can offer a Price Range Between 82.603125 and 100.959375 To this Freelancer
# You can offer a Price Range Between 95.709375 and 116.978125 To this Freelancer
# You can offer a Price Range Between 12.65625 and 15.46875 To this Freelancer
# You can offer a Price Range Between 79.228125 and 96.834375 To this Freelancer
# You can offer a Price Range Between 35.128125 and 42.934375 To this Freelancer
# You can offer a Price Range Between 32.090625 and 39.221875 To this Freelancer
# You can offer a Price Range Between 42.553125 and 52.009375 To this Freelancer
# You can offer a Price Range Between 46.096875 and 56.340625 To this Freelancer
# You can offer a Price Range Between 5.990625 and 7.321875 To this Freelancer
# You can offer a Price Range Between 128.390625 and 156.921875 To this Freelancer
# You can offer a Price Range Between 8.409375 and 10.278125 To this Freelancer
# You can offer a Price Range Between 41.653125 and 50.909375 To this Freelancer
# You can offer a Price Range Between 3.99375 and 4.88125 To this Freelancer
# You can offer a Price Range Between 43.565625 and 53.246875 To this Freelancer
# You can offer a Price Range Between 138.628125 and 169.434375 To this Freelancer
# You can offer a Price Range Between 43.790625 and 53.521875 To this Freelancer
# You can offer a Price Range Between 80.71875 and 98.65625 To this Freelancer
# You can offer a Price Range Between 65.390625 and 79.921875 To this Freelancer
# You can offer a Price Range Between 94.246875 and 115.190625 To this Freelancer
# You can offer a Price Range Between 34.228125 and 41.834375 To this Freelancer
# You can offer a Price Range Between 89.578125 and 109.484375 To this Freelancer
# You can offer a Price Range Between 30.178125 and 36.884375 To this Freelancer
# You can offer a Price Range Between 17.1 and 20.9 To this Freelancer
# You can offer a Price Range Between 84.571875 and 103.365625 To this Freelancer
# You can offer a Price Range Between 16.565625 and 20.246875 To this Freelancer
# You can offer a Price Range Between 69.946875 and 85.490625 To this Freelancer
# You can offer a Price Range Between 41.990625 and 51.321875 To this Freelancer
# You can offer a Price Range Between 55.490625 and 67.821875 To this Freelancer
# You can offer a Price Range Between 8.184375 and 10.003125 To this Freelancer
# You can offer a Price Range Between 61.565625 and 75.246875 To this Freelancer
# You can offer a Price Range Between 34.509375 and 42.178125 To this Freelancer
# You can offer a Price Range Between 38.953125 and 47.609375 To this Freelancer
# You can offer a Price Range Between 63.478125 and 77.584375 To this Freelancer
# You can offer a Price Range Between 68.203125 and 83.359375 To this Freelancer
# You can offer a Price Range Between 58.89375 and 71.98125 To this Freelancer
# You can offer a Price Range Between 23.090625 and 28.221875 To this Freelancer
# You can offer a Price Range Between 73.715625 and 90.096875 To this Freelancer
# You can offer a Price Range Between 64.265625 and 78.546875 To this Freelancer
# You can offer a Price Range Between 49.865625 and 60.946875 To this Freelancer
# You can offer a Price Range Between 92.615625 and 113.196875 To this Freelancer
# You can offer a Price Range Between 21.403125 and 26.159375 To this Freelancer
# You can offer a Price Range Between 43.565625 and 53.246875 To this Freelancer
# You can offer a Price Range Between 58.246875 and 71.190625 To this Freelancer
# You can offer a Price Range Between 28.603125 and 34.959375 To this Freelancer
# You can offer a Price Range Between 57.684375 and 70.503125 To this Freelancer
# You can offer a Price Range Between 104.203125 and 127.359375 To this Freelancer
# You can offer a Price Range Between 33.665625 and 41.146875 To this Freelancer
# You can offer a Price Range Between 43.565625 and 53.246875 To this Freelancer
# You can offer a Price Range Between 82.828125 and 101.234375 To this Freelancer
# You can offer a Price Range Between 132.159375 and 161.528125 To this Freelancer
# You can offer a Price Range Between 60.665625 and 74.146875 To this Freelancer
# You can offer a Price Range Between 14.371875 and 17.565625 To this Freelancer
# You can offer a Price Range Between 57.684375 and 70.503125 To this Freelancer
# You can offer a Price Range Between 15.8625 and 19.3875 To this Freelancer
# You can offer a Price Range Between 29.053125 and 35.509375 To this Freelancer
# You can offer a Price Range Between 32.203125 and 39.359375 To this Freelancer
# You can offer a Price Range Between 41.540625 and 50.771875 To this Freelancer
# You can offer a Price Range Between 78.665625 and 96.146875 To this Freelancer
# You can offer a Price Range Between 107.353125 and 131.209375 To this Freelancer
# You can offer a Price Range Between 13.528125 and 16.534375 To this Freelancer
# You can offer a Price Range Between 94.809375 and 115.878125 To this Freelancer
# You can offer a Price Range Between 60.328125 and 73.734375 To this Freelancer
# You can offer a Price Range Between 56.953125 and 69.609375 To this Freelancer
# You can offer a Price Range Between 88.228125 and 107.834375 To this Freelancer
# You can offer a Price Range Between 35.015625 and 42.796875 To this Freelancer
# You can offer a Price Range Between 43.621875 and 53.315625 To this Freelancer
# You can offer a Price Range Between 25.453125 and 31.109375 To this Freelancer
# You can offer a Price Range Between 40.415625 and 49.396875 To this Freelancer
# You can offer a Price Range Between 38.8546875 and 47.4890625 To this Freelancer
# You can offer a Price Range Between 140.146875 and 171.290625 To this Freelancer
# You can offer a Price Range Between 139.753125 and 170.809375 To this Freelancer
# You can offer a Price Range Between 18.3234375 and 22.3953125 To this Freelancer
# You can offer a Price Range Between 85.528125 and 104.534375 To this Freelancer
# You can offer a Price Range Between 14.821875 and 18.115625 To this Freelancer
# You can offer a Price Range Between 47.953125 and 58.609375 To this Freelancer
# You can offer a Price Range Between 14.203125 and 17.359375 To this Freelancer
# You can offer a Price Range Between 46.940625 and 57.371875 To this Freelancer
# You can offer a Price Range Between 53.240625 and 65.071875 To this Freelancer
# You can offer a Price Range Between 83.221875 and 101.715625 To this Freelancer
# You can offer a Price Range Between 20.334375 and 24.853125 To this Freelancer
# You can offer a Price Range Between 74.728125 and 91.334375 To this Freelancer
# You can offer a Price Range Between 73.715625 and 90.096875 To this Freelancer
# You can offer a Price Range Between 80.915625 and 98.896875 To this Freelancer
# You can offer a Price Range Between 42.553125 and 52.009375 To this Freelancer
# You can offer a Price Range Between 72.871875 and 89.065625 To this Freelancer
# You can offer a Price Range Between 41.9203125 and 51.2359375 To this Freelancer
# You can offer a Price Range Between 52.6078125 and 64.2984375 To this Freelancer
# You can offer a Price Range Between 43.790625 and 53.521875 To this Freelancer
# You can offer a Price Range Between 63.6046875 and 77.7390625 To this Freelancer
# You can offer a Price Range Between 161.353125 and 197.209375 To this Freelancer
# You can offer a Price Range Between 82.603125 and 100.959375 To this Freelancer
# You can offer a Price Range Between 26.465625 and 32.346875 To this Freelancer
# You can offer a Price Range Between 65.840625 and 80.471875 To this Freelancer
# You can offer a Price Range Between 25.228125 and 30.834375 To this Freelancer
# You can offer a Price Range Between 96.328125 and 117.734375 To this Freelancer
# You can offer a Price Range Between 123.1875 and 150.5625 To this Freelancer
# You can offer a Price Range Between 72.45 and 88.55 To this Freelancer
# You can offer a Price Range Between 62.353125 and 76.209375 To this Freelancer
# You can offer a Price Range Between 63.703125 and 77.859375 To this Freelancer
# You can offer a Price Range Between 77.878125 and 95.184375 To this Freelancer
# You can offer a Price Range Between 47.278125 and 57.784375 To this Freelancer
# You can offer a Price Range Between 108.703125 and 132.859375 To this Freelancer
# You can offer a Price Range Between 78.496875 and 95.940625 To this Freelancer
# You can offer a Price Range Between 22.134375 and 27.053125 To this Freelancer
# You can offer a Price Range Between 42.778125 and 52.284375 To this Freelancer
# You can offer a Price Range Between 55.96875 and 68.40625 To this Freelancer
# You can offer a Price Range Between 41.371875 and 50.565625 To this Freelancer
# You can offer a Price Range Between 41.146875 and 50.290625 To this Freelancer
# You can offer a Price Range Between 60.103125 and 73.459375 To this Freelancer
# You can offer a Price Range Between 40.359375 and 49.328125 To this Freelancer
# You can offer a Price Range Between 36.534375 and 44.653125 To this Freelancer
# You can offer a Price Range Between 8.634375 and 10.553125 To this Freelancer
# You can offer a Price Range Between 43.790625 and 53.521875 To this Freelancer
# You can offer a Price Range Between 58.9640625 and 72.0671875 To this Freelancer
# You can offer a Price Range Between 61.565625 and 75.246875 To this Freelancer
# You can offer a Price Range Between 60.103125 and 73.459375 To this Freelancer
# You can offer a Price Range Between 24.159375 and 29.528125 To this Freelancer
# You can offer a Price Range Between 32.653125 and 39.909375 To this Freelancer
# You can offer a Price Range Between 63.028125 and 77.034375 To this Freelancer
# You can offer a Price Range Between 77.653125 and 94.909375 To this Freelancer
# You can offer a Price Range Between 68.990625 and 84.321875 To this Freelancer
# You can offer a Price Range Between 16.2984375 and 19.9203125 To this Freelancer
# You can offer a Price Range Between 21.065625 and 25.746875 To this Freelancer
# You can offer a Price Range Between 45.703125 and 55.859375 To this Freelancer
# You can offer a Price Range Between 56.109375 and 68.578125 To this Freelancer
# You can offer a Price Range Between 72.478125 and 88.584375 To this Freelancer
# You can offer a Price Range Between 20.053125 and 24.509375 To this Freelancer
# You can offer a Price Range Between 31.753125 and 38.809375 To this Freelancer
# You can offer a Price Range Between 38.053125 and 46.509375 To this Freelancer
# You can offer a Price Range Between 73.4625 and 89.7875 To this Freelancer
# You can offer a Price Range Between 71.803125 and 87.759375 To this Freelancer
# You can offer a Price Range Between 52.115625 and 63.696875 To this Freelancer
# You can offer a Price Range Between 50.934375 and 62.253125 To this Freelancer
# You can offer a Price Range Between 60.778125 and 74.284375 To this Freelancer
# You can offer a Price Range Between 28.603125 and 34.959375 To this Freelancer
# You can offer a Price Range Between 48.853125 and 59.709375 To this Freelancer
# You can offer a Price Range Between 45.928125 and 56.134375 To this Freelancer
# You can offer a Price Range Between 53.015625 and 64.796875 To this Freelancer
# You can offer a Price Range Between 100.828125 and 123.234375 To this Freelancer
# You can offer a Price Range Between 48.8953125 and 59.7609375 To this Freelancer
# You can offer a Price Range Between 37.715625 and 46.096875 To this Freelancer
# You can offer a Price Range Between 62.915625 and 76.896875 To this Freelancer
# You can offer a Price Range Between 68.653125 and 83.909375 To this Freelancer
# You can offer a Price Range Between 66.403125 and 81.159375 To this Freelancer
# You can offer a Price Range Between 50.540625 and 61.771875 To this Freelancer
# You can offer a Price Range Between 106.340625 and 129.971875 To this Freelancer
# You can offer a Price Range Between 80.353125 and 98.209375 To this Freelancer
# You can offer a Price Range Between 45.253125 and 55.309375 To this Freelancer
# You can offer a Price Range Between 90.253125 and 110.309375 To this Freelancer
# You can offer a Price Range Between 59.315625 and 72.496875 To this Freelancer
# You can offer a Price Range Between 72.703125 and 88.859375 To this Freelancer
# You can offer a Price Range Between 72.7734375 and 88.9453125 To this Freelancer
# You can offer a Price Range Between 78.384375 and 95.803125 To this Freelancer
# You can offer a Price Range Between 351.928125 and 430.134375 To this Freelancer
# You can offer a Price Range Between 79.790625 and 97.521875 To this Freelancer
# You can offer a Price Range Between 95.878125 and 117.184375 To this Freelancer
# You can offer a Price Range Between 33.890625 and 41.421875 To this Freelancer
# You can offer a Price Range Between 40.55625 and 49.56875 To this Freelancer
# You can offer a Price Range Between 65.840625 and 80.471875 To this Freelancer
# You can offer a Price Range Between 22.978125 and 28.084375 To this Freelancer
# You can offer a Price Range Between 21.178125 and 25.884375 To this Freelancer
# You can offer a Price Range Between 34.059375 and 41.628125 To this Freelancer
# You can offer a Price Range Between 19.153125 and 23.409375 To this Freelancer
# You can offer a Price Range Between 82.1109375 and 100.3578125 To this Freelancer
# You can offer a Price Range Between 62.38125 and 76.24375 To this Freelancer
# You can offer a Price Range Between 15.215625 and 18.596875 To this Freelancer
# You can offer a Price Range Between 55.378125 and 67.684375 To this Freelancer
# You can offer a Price Range Between 44.775 and 54.725 To this Freelancer
# You can offer a Price Range Between 58.528125 and 71.534375 To this Freelancer
# You can offer a Price Range Between 12.403125 and 15.159375 To this Freelancer
# You can offer a Price Range Between 45.253125 and 55.309375 To this Freelancer
# You can offer a Price Range Between 48.065625 and 58.746875 To this Freelancer
# You can offer a Price Range Between 52.171875 and 63.765625 To this Freelancer
# You can offer a Price Range Between 59.203125 and 72.359375 To this Freelancer
# You can offer a Price Range Between 52.340625 and 63.971875 To this Freelancer
# You can offer a Price Range Between 38.390625 and 46.921875 To this Freelancer
# You can offer a Price Range Between 54.365625 and 66.446875 To this Freelancer
# You can offer a Price Range Between 38.615625 and 47.196875 To this Freelancer
# You can offer a Price Range Between 60.553125 and 74.009375 To this Freelancer
# You can offer a Price Range Between 10.209375 and 12.478125 To this Freelancer
# You can offer a Price Range Between 43.003125 and 52.559375 To this Freelancer
# You can offer a Price Range Between 25.790625 and 31.521875 To this Freelancer
# You can offer a Price Range Between 50.540625 and 61.771875 To this Freelancer
# You can offer a Price Range Between 22.528125 and 27.534375 To this Freelancer
# You can offer a Price Range Between 81.759375 and 99.928125 To this Freelancer
# You can offer a Price Range Between 29.503125 and 36.059375 To this Freelancer
# You can offer a Price Range Between 67.978125 and 83.084375 To this Freelancer
# You can offer a Price Range Between 38.165625 and 46.646875 To this Freelancer
# You can offer a Price Range Between 41.821875 and 51.115625 To this Freelancer
# You can offer a Price Range Between 43.565625 and 53.246875 To this Freelancer
# You can offer a Price Range Between 40.078125 and 48.984375 To this Freelancer
# You can offer a Price Range Between 42.553125 and 52.009375 To this Freelancer
# You can offer a Price Range Between 23.428125 and 28.634375 To this Freelancer
# You can offer a Price Range Between 14.203125 and 17.359375 To this Freelancer
# You can offer a Price Range Between 66.121875 and 80.815625 To this Freelancer
# You can offer a Price Range Between 64.321875 and 78.615625 To this Freelancer
# You can offer a Price Range Between 3.628125 and 4.434375 To this Freelancer
# You can offer a Price Range Between 7.790625 and 9.521875 To this Freelancer
# You can offer a Price Range Between 40.190625 and 49.121875 To this Freelancer
# You can offer a Price Range Between 95.653125 and 116.909375 To this Freelancer
# You can offer a Price Range Between 39.43125 and 48.19375 To this Freelancer
# You can offer a Price Range Between 4.978125 and 6.084375 To this Freelancer
# You can offer a Price Range Between 48.178125 and 58.884375 To this Freelancer
# You can offer a Price Range Between 70.903125 and 86.659375 To this Freelancer
# You can offer a Price Range Between 18.815625 and 22.996875 To this Freelancer
# You can offer a Price Range Between 99.646875 and 121.790625 To this Freelancer
# You can offer a Price Range Between 112.753125 and 137.809375 To this Freelancer
# You can offer a Price Range Between 109.884375 and 134.303125 To this Freelancer
# You can offer a Price Range Between 20.615625 and 25.196875 To this Freelancer
# You can offer a Price Range Between 127.153125 and 155.409375 To this Freelancer
# You can offer a Price Range Between 49.978125 and 61.084375 To this Freelancer
# You can offer a Price Range Between 94.190625 and 115.121875 To this Freelancer
# You can offer a Price Range Between 34.678125 and 42.384375 To this Freelancer
# You can offer a Price Range Between 77.540625 and 94.771875 To this Freelancer
# You can offer a Price Range Between 82.0125 and 100.2375 To this Freelancer
# You can offer a Price Range Between 51.890625 and 63.421875 To this Freelancer
# You can offer a Price Range Between 4.584375 and 5.603125 To this Freelancer
# You can offer a Price Range Between 40.640625 and 49.671875 To this Freelancer
# You can offer a Price Range Between 59.9484375 and 73.2703125 To this Freelancer
# You can offer a Price Range Between 23.4140625 and 28.6171875 To this Freelancer
# You can offer a Price Range Between 52.059375 and 63.628125 To this Freelancer
# You can offer a Price Range Between 64.603125 and 78.959375 To this Freelancer
# You can offer a Price Range Between 60.271875 and 73.665625 To this Freelancer
# You can offer a Price Range Between 34.678125 and 42.384375 To this Freelancer
# You can offer a Price Range Between 65.390625 and 79.921875 To this Freelancer
# You can offer a Price Range Between 26.1 and 31.9 To this Freelancer
# You can offer a Price Range Between 14.765625 and 18.046875 To this Freelancer
# You can offer a Price Range Between 72.253125 and 88.309375 To this Freelancer
# You can offer a Price Range Between 61.565625 and 75.246875 To this Freelancer
# You can offer a Price Range Between 41.653125 and 50.909375 To this Freelancer
# You can offer a Price Range Between 45.928125 and 56.134375 To this Freelancer
# You can offer a Price Range Between 45.4078125 and 55.4984375 To this Freelancer
# You can offer a Price Range Between 28.603125 and 34.959375 To this Freelancer
# You can offer a Price Range Between 99.5765625 and 121.7046875 To this Freelancer
# You can offer a Price Range Between 72.253125 and 88.309375 To this Freelancer
# You can offer a Price Range Between 35.015625 and 42.796875 To this Freelancer
# You can offer a Price Range Between 29.840625 and 36.471875 To this Freelancer
# You can offer a Price Range Between 24.215625 and 29.596875 To this Freelancer
# You can offer a Price Range Between 60.103125 and 73.459375 To this Freelancer
# You can offer a Price Range Between 8.015625 and 9.796875 To this Freelancer
# You can offer a Price Range Between 71.353125 and 87.209375 To this Freelancer
# You can offer a Price Range Between 61.509375 and 75.178125 To this Freelancer
# You can offer a Price Range Between 105.665625 and 129.146875 To this Freelancer
# You can offer a Price Range Between 11.615625 and 14.196875 To this Freelancer
# You can offer a Price Range Between 37.940625 and 46.371875 To this Freelancer
# You can offer a Price Range Between 29.98125 and 36.64375 To this Freelancer
# You can offer a Price Range Between 47.446875 and 57.990625 To this Freelancer
# You can offer a Price Range Between 5.990625 and 7.321875 To this Freelancer
# You can offer a Price Range Between 65.165625 and 79.646875 To this Freelancer
# You can offer a Price Range Between 84.009375 and 102.678125 To this Freelancer
# You can offer a Price Range Between 62.184375 and 76.003125 To this Freelancer
# You can offer a Price Range Between 48.43125 and 59.19375 To this Freelancer
# You can offer a Price Range Between 16.48125 and 20.14375 To this Freelancer
# You can offer a Price Range Between 82.434375 and 100.753125 To this Freelancer
# You can offer a Price Range Between 39.853125 and 48.709375 To this Freelancer
# You can offer a Price Range Between 72.084375 and 88.103125 To this Freelancer
# You can offer a Price Range Between 60.103125 and 73.459375 To this Freelancer
# You can offer a Price Range Between 69.271875 and 84.665625 To this Freelancer
# You can offer a Price Range Between 55.828125 and 68.234375 To this Freelancer
# You can offer a Price Range Between 41.11875 and 50.25625 To this Freelancer
# You can offer a Price Range Between 87.103125 and 106.459375 To this Freelancer
# You can offer a Price Range Between 54.815625 and 66.996875 To this Freelancer
# You can offer a Price Range Between 66.403125 and 81.159375 To this Freelancer
# You can offer a Price Range Between 26.409375 and 32.278125 To this Freelancer
# You can offer a Price Range Between 46.040625 and 56.271875 To this Freelancer
# You can offer a Price Range Between 77.203125 and 94.359375 To this Freelancer
# You can offer a Price Range Between 40.696875 and 49.740625 To this Freelancer
# You can offer a Price Range Between 77.7796875 and 95.0640625 To this Freelancer
# You can offer a Price Range Between 74.953125 and 91.609375 To this Freelancer
# You can offer a Price Range Between 18.815625 and 22.996875 To this Freelancer
# You can offer a Price Range Between 8.296875 and 10.140625 To this Freelancer
# You can offer a Price Range Between 81.8578125 and 100.0484375 To this Freelancer
# You can offer a Price Range Between 88.003125 and 107.559375 To this Freelancer
# You can offer a Price Range Between 15.553125 and 19.009375 To this Freelancer
# You can offer a Price Range Between 53.38125 and 65.24375 To this Freelancer
# You can offer a Price Range Between 79.228125 and 96.834375 To this Freelancer
# You can offer a Price Range Between 67.978125 and 83.084375 To this Freelancer
# You can offer a Price Range Between 75.571875 and 92.365625 To this Freelancer
# You can offer a Price Range Between 29.446875 and 35.990625 To this Freelancer
# You can offer a Price Range Between 21.825 and 26.675 To this Freelancer
# You can offer a Price Range Between 66.740625 and 81.571875 To this Freelancer
# You can offer a Price Range Between 18.590625 and 22.721875 To this Freelancer
# You can offer a Price Range Between 60.103125 and 73.459375 To this Freelancer
# You can offer a Price Range Between 68.990625 and 84.321875 To this Freelancer
# You can offer a Price Range Between 80.690625 and 98.621875 To this Freelancer
# You can offer a Price Range Between 70.228125 and 85.834375 To this Freelancer
# You can offer a Price Range Between 8.296875 and 10.140625 To this Freelancer
# You can offer a Price Range Between 55.884375 and 68.303125 To this Freelancer
# You can offer a Price Range Between 28.153125 and 34.409375 To this Freelancer
# You can offer a Price Range Between 22.134375 and 27.053125 To this Freelancer
# You can offer a Price Range Between 22.471875 and 27.465625 To this Freelancer
# You can offer a Price Range Between 20.503125 and 25.059375 To this Freelancer
# You can offer a Price Range Between 88.903125 and 108.659375 To this Freelancer
# You can offer a Price Range Between 36.253125 and 44.309375 To this Freelancer
# You can offer a Price Range Between 45.759375 and 55.928125 To this Freelancer
# You can offer a Price Range Between 60.890625 and 74.421875 To this Freelancer
# You can offer a Price Range Between 66.88125 and 81.74375 To this Freelancer
# You can offer a Price Range Between 80.071875 and 97.865625 To this Freelancer
# You can offer a Price Range Between 32.315625 and 39.496875 To this Freelancer

# %% [markdown]
# # ---------------------------------------------END---------------------------------------------
